# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/vidhi/college baby/sem 6/Topics in EconRes/FinalPaperMaterial/Data/Mittal et al data/panchayat_ID_MIS_index_mapping.csv', usecols=range(9))
df.head()
# Out:
#   Panchayat_ID Gram_panchayat_name Subdistrict census code Subdistrict name  \
# 0       221810      pitchikalapadu                    4730         Yetapaka
# 1       221811         kannaigudem                    4730         Yetapaka
# 2       221812          laxmipuram                    4730         Yetapaka
# 3       221813     ramagopalapuram                    4730         Yetapaka
# 4       221814          nallakunta                    4730         Yetapaka
#
#   District census code  District name State census code      State name  \
# 0                  541  visakhapatnam                28  andhra pradesh
# 1                  541  visakhapatnam                28  andhra pradesh
# 2                  541  visakhapatnam                28  andhra pradesh
# 3                  541  visakhapatnam                28  andhra pradesh
# 4                  541  visakhapatnam                28  andhra pradesh
#
#   mis_index
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# ...

# %%
df.describe()
# Out:
#        Panchayat_ID Gram_panchayat_name Subdistrict census code  \
# count        217930              217458                  217930
# unique       209749              153584                    4816
# top          106350              kochas                     202
# freq              2                1053                     535
#
#        Subdistrict name District census code District name State census code  \
# count            217930               217930        217619            217930
# unique             5161                  860           853               432
# top             Lalganj                  191      azamgarh                 9
# freq                823                 1855          1855             57611
#
#            State name mis_index
# count          217930    115223
# unique            432    109732
# top     uttar pradesh     451.0
# freq            57611         3

# %%
df.to_csv('/Users/vidhi/college baby/sem 6/Topics in EconRes/FinalPaperMaterial/Data/Mittal et al data/panchayat_ID_MIS_index_mapping.csv', index=False)
